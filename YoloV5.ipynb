yciHCi8YfAC18hY5Q7X1FELcoM71J14yN3gf-XuB42rMzABszrXhVziLDKeQoUgvP0H9Muv7YlY5gcgFcqyWeWVSsNn3IELGUVMp9Bc31qgUCDaRsscE-8sfqwFnxHYq2Q; SIDCC=ABTWhQEsV75A1afmBmB82pVT2Ifpqi-aB_Avdndd7vS1DG7kzwgOzvnn9EGbIxZH39_aQtJUiuJl; __Secure-1PSIDCC=ABTWhQF6RbSlFubVDhKDTfgtrQxDyO9RVFbg4TnRjGuCPdo1k96BEPA_sBP20rF-PNe3Ky8M2JM; __Secure-3PSIDCC=ABTWhQEdCowykfrLemy0aL2tYyZlrws8Fx8NCGyufsqqyydPxQzvnk47ug8OowUcjo4IuGcg0BI" --header="Connection: keep-alive" "https://drive.usercontent.google.com/download?id=1PanE-7qqAb6aJu_JtdEOLNkrjXTJfcJu&export=download&authuser=0&confirm=t&uuid=5cbe673a-36bd-4e01-8230-f4d050ca5363&at=APZUnTU12zL6QJ8B0xucsJ6LpkxQ:1707388535971" -c -O 'car damage.zip'
# Out:
# --2024-02-08 16:56:38--  https://drive.usercontent.google.com/download?id=1PanE-7qqAb6aJu_JtdEOLNkrjXTJfcJu&export=download&authuser=0&confirm=t&uuid=5cbe673a-36bd-4e01-8230-f4d050ca5363&at=APZUnTU12zL6QJ8B0xucsJ6LpkxQ:1707388535971
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.69.132, 2607:f8b0:4001:c0d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.69.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117563964 (112M) [application/octet-stream]
# Saving to: ‘car damage.zip’
#
# car damage.zip      100%[===================>] 112.12M  40.7MB/s    in 2.8s
#
# 2024-02-08 16:56:42 (40.7 MB/s) - ‘car damage.zip’ saved [117563964/117563964]

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-283-g875d9278 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
# %cd ..
# Out:
# /content

# %%
import shutil
import os, sys

zip_file = "car damage.zip"

if os.path.isfile(zip_file):
  shutil.unpack_archive(zip_file, "data")
else:
  print(zip_file + " not found")

# %%
# %cd yolov5
# !python train.py --img 640 --batch 8 --epochs 150 --data ../data.yaml --weights yolov5s.pt
# Out:
# [Errno 2] No such file or directory: 'yolov5'
# /content/yolov5
# 2024-02-08 13:09:36.621674: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-08 13:09:36.621731: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-08 13:09:36.623030: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.4 --source /content/carscratch.jpg
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/carscratch.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-283-g875d9278 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/carscratch.jpg: 448x640 1 Scratch, 45.1ms
# Speed: 0.5ms pre-process, 45.1ms inference, 451.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp3

# %%
from IPython.display import display
from PIL import Image

image_path = "/content/yolov5/runs/detect/exp3/carscratch.jpg"
display(Image.open(image_path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=540x360>
